# %%
import pandas as pd

# %%
#read file from file but from sheet1
df = pd.read_excel(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Attribute DataSet.xlsx')
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#different sheet
pd.read_excel(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Attribute DataSet.xlsx',sheet_name = 'Sheet2', header = None, names = ['A','B'])
# Out:
#         A       B
# 0   sdnvl    bdbg
# 1  dfgfdb    bdgb
# 2     dfb  fbgbdf
# 3     ffd     454

# %%
#read 2 records
df.head(2)
#last 2
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
#read csv file
pd.read_csv(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\haberman.csv', header = None, names = ["Age", "Patient's year of operation", "Number of positive axillary nodes detected","Survival status"])
# Out:
#      Age  Patient's year of operation  \
# 0     30                           64
# 1     30                           62
# 2     30                           65
# 3     31                           59
# 4     31                           65
# ..   ...                          ...
# 301   75                           62
# 302   76                           67
# 303   77                           65
# 304   78                           65
# 305   83                           58
#
#      Number of positive axillary nodes detected  Survival status
# 0                                             1                1
# 1                                             3                1
# 2                                             0                1
# 3                                             2                1
# 4                                             4                1
# ..                                          ...              ...
# ...

# %%
#read dataset from github
pd.read_csv(r'https://gist.githubusercontent.com/rnirmal/e01acfdaf54a6f9b24e91ba4cae63518/raw/6b589a5c5a851711e20c5eb28f9d54742d1fe2dc/datasets.csv')
# Out:
#            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %%
#read from html link
pd.read_html(r'https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
a=pd.read_html(r'https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# read out a json data
js = pd.read_json(r'https://api.github.com/repos/pandas-dev/pandas/issues')
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
#read inside 'user' column we have values 
js = pd.read_json(r'https://api.github.com/repos/pandas-dev/pandas/issues')
js['user']
# Out:
# 0     {'login': 'shiersansi', 'id': 143710553, 'node...
# 1     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2     {'login': 'davidboweninrupt', 'id': 76816026, ...
# 3     {'login': 'loco-philippe', 'id': 92333742, 'no...
# 4     {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 5     {'login': 'jorisvandenbossche', 'id': 1020496,...
# 6     {'login': 'RedGuy12', 'id': 61329810, 'node_id...
# 7     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 8     {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 9     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 10    {'login': 'koizumihiroo', 'id': 35495924, 'nod...
# 11    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 12    {'login': 'rsm-23', 'id': 136445532, 'node_id'...
# 13    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14    {'login': 'josemayer', 'id': 75316256, 'node_i...
# 15    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 16    {'login': 'nmacholl', 'id': 1160474, 'node_id'...
# ...

# %%
df
# Out:
#     name  salary       email addr
# 0  frank     100   frank@abc  blr
# 1  shank     200  shank1@abc  blr
# 2   tank     300    tank@abc  blr

# %%
# convert to json and it saves in localhost
df.to_json('test.json')

# %%
# to check the json file 
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 2
#       1 # to check the json file
# ----> 2 pwd
#
# NameError: name 'pwd' is not defined

# %%
df

# %%
# to store data in particular place
df.to_csv("D://7-zip//test.csv")

# %%
dt = pd.read_csv(r'')

# %%
df

# %%
df.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
# show one or two columns
df[['Size','Style']]
# Out:
#      Size    Style
# 0       M     Sexy
# 1       L   Casual
# 2       L  vintage
# 3       L    Brief
# 4       M     cute
# ..    ...      ...
# 495     M   Casual
# 496  free     Sexy
# 497     M   Casual
# 498     L   Casual
# 499  free   Casual
#
# [500 rows x 2 columns]

# %%
type(df['Size'])
# Out:
# pandas.core.series.Series

# %%
#dt of every columns
df.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
df[['Style']]
# dataframe type
# Out:
#        Style
# 0       Sexy
# 1     Casual
# 2    vintage
# 3      Brief
# 4       cute
# ..       ...
# 495   Casual
# 496     Sexy
# 497   Casual
# 498   Casual
# 499   Casual
#
# [500 rows x 1 columns]

# %%
# Analytics abount only  int/float  datatype in df
df.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  5.000000e+02  500.000000      500.000000
# mean   9.055417e+08    3.528600        0.420000
# std    1.736190e+08    2.005364        0.494053
# min    4.442820e+08    0.000000        0.000000
# 25%    7.673164e+08    3.700000        0.000000
# 50%    9.083296e+08    4.600000        0.000000
# 75%    1.039534e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %%
#return true where object else false
df.dtypes=='object'
# Out:
# Dress_ID          False
# Style              True
# Price              True
# Rating            False
# Size               True
# Season             True
# NeckLine           True
# SleeveLength       True
# waiseline          True
# Material           True
# FabricType         True
# Decoration         True
# Pattern Type       True
# Recommendation    False
# dtype: bool

# %%
#return only object data-type
df.dtypes[df.dtypes == 'object']
# Out:
# Style           object
# Price           object
# Size            object
# Season          object
# NeckLine        object
# SleeveLength    object
# waiseline       object
# Material        object
# FabricType      object
# Decoration      object
# Pattern Type    object
# dtype: object

# %%
# list of all columns where dt = object
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Style', 'Price', 'Size', 'Season', 'NeckLine', 'SleeveLength',
#        'waiseline', 'Material', 'FabricType', 'Decoration', 'Pattern Type'],
#       dtype='object')

# %%
# extract dataset where dt == object
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#        Style    Price  Size  Season   NeckLine SleeveLength waiseline  \
# 0       Sexy      Low     M  Summer     o-neck    sleevless    empire
# 1     Casual      Low     L  Summer     o-neck        Petal   natural
# 2    vintage     High     L  Automn     o-neck         full   natural
# 3      Brief  Average     L  Spring     o-neck         full   natural
# 4       cute      Low     M  Summer     o-neck    butterfly   natural
# ..       ...      ...   ...     ...        ...          ...       ...
# 495   Casual      Low     M  Spring     o-neck         full   natural
# 496     Sexy      Low  free  Summer     o-neck         full    empire
# 497   Casual  Average     M  Summer     v-neck         full    empire
# 498   Casual  Average     L  winter  boat-neck    sleevless    empire
# 499   Casual      Low  free  Summer     v-neck        short    empire
#
#           Material  FabricType  Decoration Pattern Type
# 0              NaN     chiffon     ruffles       animal
# ...

# %%
# 
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#          Style    Price Size  Season NeckLine SleeveLength waiseline Material  \
# count      500      498  500     498      497          498       413      372
# unique      13        7    7       8       16           17         4       23
# top     Casual  Average    M  Summer   o-neck    sleevless   natural   cotton
# freq       232      252  177     159      271          223       304      152
#
#        FabricType Decoration Pattern Type
# count         234        264          391
# unique         22         24           14
# top       chiffon       lace        solid
# freq          135         70          203

# %%
df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#            Rating
# count  500.000000
# mean     3.528600
# std      2.005364
# min      0.000000
# 25%      3.700000
# 50%      4.600000
# 75%      4.800000
# max      5.000000

# %%
#SLICING in particular dataset
df['Dress_ID'][1:10:2]
# Out:
# 1    1212192089
# 3     966005983
# 5    1068332458
# 7    1219677488
# 9     985292672
# Name: Dress_ID, dtype: int64

# %%
#add one more column name with style1 with value frank 
df['Style1'] = "frank"

# %%
#check column record is null or not
df['Dress_ID'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Dress_ID, Length: 500, dtype: bool

# %%
df1 = pd.read_excel(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Dress Sales.xlsx')

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
#where there is null data -> it is in unnamed: 26
# df1['Unnamed:26']
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#to find maximum profit/rating
#df[df['Rating']== max(df['Rating'])]

#specific need name of highest rating
df[df['Rating']== max(df['Rating'])]['Dress_ID']
# Out:
# 10     1117293701
# 14     1055411544
# 17      830467746
# 19     1113221101
# 40      943844640
# 50      841203385
# 62     1083779666
# 65     1019134411
# 70      864253055
# 76      842060995
# 80     1130994272
# 82      967999477
# 88     1018110870
# 114    1032990258
# 157     832191944
# 166    1069595866
# 176     956453735
# 196     891631697
# 198     764321904
# 202     981437831
# 203    1036456647
# 210    1043590098
# 211    1091666465
# 224    1074432879
# 228     923983419
# 232    1077555214
# 236     995964089
# 252     682561447
# 260    1053467336
# 266    1066740059
# 287     933951149
# 292    1053002876
# 294     949336768
# 303    1044288976
# 315    1024325244
# 316     841203385
# 323     856139963
# 324    1032982013
# 326     912614690
# 327    1072784739
# 328     945651303
# 358     818295153
# 372     720665176
# 378     876761815
# 393     942245416
# 394     900108476
# 410     932913675
# 413    1052420390
# 424     944641715
# 446     865490824
# ...

# %%
df.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation', 'Style1'],
#       dtype='object')

# %%
df['Season']
# Out:
# 0      Summer
# 1      Summer
# 2      Automn
# 3      Spring
# 4      Summer
#         ...
# 495    Spring
# 496    Summer
# 497    Summer
# 498    winter
# 499    Summer
# Name: Season, Length: 500, dtype: object

# %%
#where season = winter

df[df['Season'] == 'winter']
# Out:
#        Dress_ID     Style      Price  Rating  Size  Season        NeckLine  \
# 147   897981100    Casual    Average     4.8     L  winter          v-neck
# 148   973481686   vintage    Average     4.3  free  winter          o-neck
# 194   541172235    Casual    Average     4.7     M  winter          o-neck
# 195   727676110    Casual        low     4.6  free  winter          o-neck
# 198   764321904      Sexy    Average     5.0     L  winter          o-neck
# 237   868453353    Casual        Low     4.9  free  winter          o-neck
# 239   685606338    Casual     Medium     4.6     M  winter          o-neck
# 240   877962269    Casual    Average     4.7     M  winter          v-neck
# 241   995644296      Sexy    Average     4.7     M  winter          v-neck
# 242  1066273951    Casual    Average     3.5     M  winter          v-neck
# 243   822176645    Casual    Average     4.8     M  winter          o-neck
# ...

# %%
#to find the lenght of winter
len(df[df['Season'] == 'winter'])
# Out:
# 46

# %%
# more than or less than --- where rating is more than 4.5
df[df['Rating'] > 4.5]
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer     o-neck
# 3     966005983     Brief  Average     4.6     L  Spring     o-neck
# 10   1117293701     party  Average     5.0  free  Summer     o-neck
# 12    957723897      sexy      Low     4.7     M  Winter     o-neck
# 13    749031896   vintage  Average     4.8     M  Summer     o-neck
# ..          ...       ...      ...     ...   ...     ...        ...
# 493   817353671  bohemian      Low     4.6  free  Summer     o-neck
# 494   990559192     Brief  Average     4.7     M  winter     o-neck
# 495   713391965    Casual      Low     4.7     M  Spring     o-neck
# 497   532874347    Casual  Average     4.7     M  Summer     v-neck
# 498   655464934    Casual  Average     4.6     L  winter  boat-neck
#
#      SleeveLength waiseline  Material  FabricType  Decoration Pattern Type  \
# ...

# %%
#check 2 condition using &
df[(df['Rating'] > 4.5) & (df['Recommendation'] == 1)]
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer     o-neck
# 3     966005983     Brief  Average     4.6     L  Spring     o-neck
# 12    957723897      sexy      Low     4.7     M  Winter     o-neck
# 13    749031896   vintage  Average     4.8     M  Summer     o-neck
# 16    624314841      cute  Average     4.7     L  spring     o-neck
# ..          ...       ...      ...     ...   ...     ...        ...
# 491   964917582    Casual  Average     5.0     L  Summer     o-neck
# 493   817353671  bohemian      Low     4.6  free  Summer     o-neck
# 495   713391965    Casual      Low     4.7     M  Spring     o-neck
# 497   532874347    Casual  Average     4.7     M  Summer     v-neck
# 498   655464934    Casual  Average     4.6     L  winter  boat-neck
#
#      SleeveLength waiseline  Material  FabricType  Decoration Pattern Type  \
# ...

# %%
#date time operation
df2 = pd.read_csv(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\AgentPerformance.csv')
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#operations in date 
#convert datetime (object) to datetime format
pd.to_datetime(df2['Date'])
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
#convert to datetime 
date = pd.to_datetime(df2['Date'])

# %%
#create one more column and add this data
df2['converted_date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#extract only a year from the dates and create one more column year_date
df2['year_date'] =  df2['converted_date'].dt.year

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#return a particular month
df2['month_date'] =  df2['converted_date'].dt.month
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#return week of year but in reversed because it shows num of week left
df2['week_date'] =  df2['converted_date'].dt.week
# Out:
# C:\Users\ferna\AppData\Local\Temp\ipykernel_13304\2909564753.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df2['week_date'] =  df2['converted_date'].dt.week

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#month wise maximum of different months
df2['month_date'].value_counts()
# Out:
# 7    2160
# Name: month_date, dtype: int64

# %%
df2.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback',
#        'converted_date', 'year_date', 'month_date', 'week_date'],
#       dtype='object')

# %%
#delete some column but it will be there in orginal data
#as it drop from current instance

#axis =0 row and axis = 1 columns

df2.drop('Total Chats', axis = 1)
# Out:
#       SL No       Date          Agent Name Average Response Time  \
# 0         1  7/30/2022        Prerna Singh               0:00:38
# 1         2  7/30/2022       Nandani Gupta               0:01:15
# 2         3  7/30/2022          Ameya Jain               0:00:30
# 3         4  7/30/2022       Mahesh Sarade               0:01:04
# 4         5  7/30/2022              Swati                0:01:11
# ...     ...        ...                 ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar               0:00:00
# 2156   2157   7/1/2022             Nitin M               0:00:00
# 2157   2158   7/1/2022              Vivek                0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                    0:04:20            4.11               9     2022-07-30
# ...

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#permanent delete
#1st reassign df to new variable 
#new_var = df2.drop('Total Chats', axis = 1)
#2nd inplace : replace it permanently

df2.drop('Total Chats', axis = 1, inplace = True)

# %%
df2
# Out:
#       SL No       Date          Agent Name Average Response Time  \
# 0         1  7/30/2022        Prerna Singh               0:00:38
# 1         2  7/30/2022       Nandani Gupta               0:01:15
# 2         3  7/30/2022          Ameya Jain               0:00:30
# 3         4  7/30/2022       Mahesh Sarade               0:01:04
# 4         5  7/30/2022              Swati                0:01:11
# ...     ...        ...                 ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar               0:00:00
# 2156   2157   7/1/2022             Nitin M               0:00:00
# 2157   2158   7/1/2022              Vivek                0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                    0:04:20            4.11               9     2022-07-30
# ...

# %%
#delete row operation perm
df2.drop(2, inplace = True)

# %%
df2
# Out:
#       SL No       Date          Agent Name Average Response Time  \
# 0         1  7/30/2022        Prerna Singh               0:00:38
# 1         2  7/30/2022       Nandani Gupta               0:01:15
# 3         4  7/30/2022       Mahesh Sarade               0:01:04
# 4         5  7/30/2022              Swati                0:01:11
# 5         6  7/30/2022             Mukesh                0:00:34
# ...     ...        ...                 ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar               0:00:00
# 2156   2157   7/1/2022             Nitin M               0:00:00
# 2157   2158   7/1/2022              Vivek                0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                    0:04:20            4.11               9     2022-07-30
# ...

# %%
#filter a record from rows

#1: loc -> take named indexes
df2.loc[[5,6]]
# Out:
#    SL No       Date       Agent Name Average Response Time  \
# 5      6  7/30/2022          Mukesh                0:00:34
# 6      7  7/30/2022  Saikumarreddy N               0:00:31
#
#   Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 5                 0:15:34            4.62               8     2022-07-30
# 6                 0:11:09            5.00              12     2022-07-30
#
#    year_date  month_date  week_date
# 5       2022           7         30
# 6       2022           7         30

# %%
#start from 5 and till 10
df2.loc[5:10]
# Out:
#     SL No       Date       Agent Name Average Response Time  \
# 5       6  7/30/2022          Mukesh                0:00:34
# 6       7  7/30/2022  Saikumarreddy N               0:00:31
# 7       8  7/30/2022    Sanjeev Kumar               0:00:55
# 8       9  7/30/2022   Shubham Sharma               0:01:31
# 9      10  7/30/2022     Nishtha Jain               0:00:59
# 10     11  7/30/2022     Manjunatha A               0:00:47
#
#    Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 5                  0:15:34            4.62               8     2022-07-30
# 6                  0:11:09            5.00              12     2022-07-30
# 7                  0:20:43            5.00               6     2022-07-30
# 8                  0:25:10            4.38               8     2022-07-30
# 9                  0:13:31            4.12              16     2022-07-30
# 10                 0:42:56            3.60               5     2022-07-30
#
# ...

# %%
df2.loc[5:14:2]
# Out:
#     SL No       Date          Agent Name Average Response Time  \
# 5       6  7/30/2022             Mukesh                0:00:34
# 7       8  7/30/2022       Sanjeev Kumar               0:00:55
# 9      10  7/30/2022        Nishtha Jain               0:00:59
# 11     12  7/30/2022      Khushboo Priya               0:01:32
# 13     14  7/30/2022  Harikrishnan Shaji               0:00:42
#
#    Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 5                  0:15:34            4.62               8     2022-07-30
# 7                  0:20:43            5.00               6     2022-07-30
# 9                  0:13:31            4.12              16     2022-07-30
# 11                 0:21:35            4.43              14     2022-07-30
# 13                 0:25:49            4.57               7     2022-07-30
#
#     year_date  month_date  week_date
# 5        2022           7         30
# 7        2022           7         30
# ...

# %%
#just need 2 coloumns || from 5 7 9
df2.loc[5:9,['converted_date','Date']]
# Out:
#   converted_date       Date
# 5     2022-07-30  7/30/2022
# 6     2022-07-30  7/30/2022
# 7     2022-07-30  7/30/2022
# 8     2022-07-30  7/30/2022
# 9     2022-07-30  7/30/2022

# %%
# iloc -> take numeric indexes
df2.iloc[5:9, 0:5:2]
# Out:
#    SL No       Agent Name Average Resolution Time
# 6      7  Saikumarreddy N                 0:11:09
# 7      8    Sanjeev Kumar                 0:20:43
# 8      9   Shubham Sharma                 0:25:10
# 9     10     Nishtha Jain                 0:13:31

# %%
df[df>100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df[df>100]
#
# File D:\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\frame.py:7582, in DataFrame._cmp_method(self, other, op)
#    7579 self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7581 # See GH#4537 for discussion of scalar op behavior
# ...

# %%
#based on null value drop columns
df2.dropna()
#drop permanently 
df2.dropna(inplace=True)
#check column and rows nan value
df2.dropna(axis=1), df2.dropna(axis=2)

#replace nan value with something
df2.fillna(value=4)
#replace nan value with df - quantity mean
df2.fillna(value=df['quantity'].mean())

# %%
#group by and find average year wise(year1, year2 etc)
#df2.groupby('converted_date')['Average Rating'].mean()
df2.groupby('converted_date')['Total Feedback'].mean()

# %%
***82nd class***

# %%
import pandas as pd

# %%
data = {'name':['frank','shank','tank'],
        'salary':[100,200,300],
        'email':['frank@abc', 'shank1@abc','tank@abc'],
        'addr' : ['blr' , 'blr' , 'blr' ]
       }

# %%
#convert into df
#name sal .... became column
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  salary       email addr
# 0  frank     100   frank@abc  blr
# 1  shank     200  shank1@abc  blr
# 2   tank     300    tank@abc  blr

# %%
#create own indexes not columns
#pd.DataFrame(data, index = [4,5,7] ) custom indexes
pd.DataFrame(data)
# Out:
#     name  salary       email addr
# 0  frank     100   frank@abc  blr
# 1  shank     200  shank1@abc  blr
# 2   tank     300    tank@abc  blr

# %%
df_attribute = pd.read_csv(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Attribute DataSet.csv')

# %%
df_attribute
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df_dress = pd.read_csv(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Dress Sales(AutoRecovered).csv')

# %%
pd_attribute = pd.DataFrame(df_attribute)
pd_attribute
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd_dress = pd.DataFrame(df_dress)
pd_dress
# Out:
#        Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 495   713391965          0          0           0         560         554
# 496   722565148          0          0           0         875         866
# 497   532874347          0          0           0         734         728
# 498   655464934          0          0           0         254         259
# 499   919930954          0          0           0         538         545
#
#      09-08-2013  09-10-2013 09-12-2013 14/9/2013  ... Unnamed: 26 Unnamed: 27  \
# ...

# %%
import os

# %%
df_attribute.to_json('attrJson.json')
os.getcwd()
# Out:
# 'C:\\Users\\ferna'

# %%
df_dress.to_json('dressJson.json')

# %%
import pymongo
# communication btw mongo and pycharm

client = pymongo.MongoClient("mongodb+srv://francisfernandes010:9560685327@frank.cvwuhcf.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-ki2thoc-shard-00-01.cvwuhcf.mongodb.net:27017', 'ac-ki2thoc-shard-00-02.cvwuhcf.mongodb.net:27017', 'ac-ki2thoc-shard-00-00.cvwuhcf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-kees4z-shard-0', tls=True), 'test')

# %%
file = pd.read_json(r'C:\Users\ferna\attrJson.json')

# %%
db = client['mytask']
collection = db["madhu"]
collection.insert_many(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 3
#       1 db = client['mytask']
#       2 collection = db["madhu"]
# ----> 3 collection.insert_many(file)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\collection.py:736, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     683 @_csot.apply
#     684 def insert_many(
#     685     self,
#    (...)
#     690     comment: Optional[Any] = None,
#     691 ) -> InsertManyResult:
#     692     """Insert an iterable of documents.
#     693
# ...

# %%
df
# Out:
#     name  salary       email addr
# 0  frank     100   frank@abc  blr
# 1  shank     200  shank1@abc  blr
# 2   tank     300    tank@abc  blr

# %%
df0 = {
    'pf_nu':[25,67,689],
    'income_tax' : [41,58,698],
     'mobile_no' : [23543,43543,454],
    'courses' : ['ds' , 'bigdata' , 'web dev ' ]
}

# %%
df0
# Out:
# {'pf_nu': [25, 67, 689],
#  'income_tax': [41, 58, 698],
#  'mobile_no': [23543, 43543, 454],
#  'courses': ['ds', 'bigdata', 'web dev ']}

# %%
df00 = pd.DataFrame(df0)

# %%
df00
# Out:
#    pf_nu  income_tax  mobile_no   courses
# 0     25          41      23543        ds
# 1     67          58      43543   bigdata
# 2    689         698        454  web dev

# %%
#concatination operation

pd.concat([df,df00], axis =1)
#axis 1 columns wise--> horizontal concat
# Out:
#     name  salary       email addr  pf_nu  income_tax  mobile_no   courses
# 0  frank     100   frank@abc  blr     25          41      23543        ds
# 1  shank     200  shank1@abc  blr     67          58      43543   bigdata
# 2   tank     300    tank@abc  blr    689         698        454  web dev

# %%
data2 = {
    '0':[25,67,689],
    '1' : [41,58,698],
     '2' : [23543,43543,454],
    '3' : ['ds' , 'bigdata' , 'web dev ' ]
}

# %%
data3 = {'0':['frank','shank','tank'],
        '1':[100,200,300],
        '2':['frank@abc', 'shank1@abc','tank@abc'],
        '3' : ['blr' , 'blr' , 'blr' ]
       }

# %%
df2 = pd.DataFrame(data2)

# %%
df3 = pd.DataFrame(data3)

# %%
pd.concat([df2,df3])
# Out:
#        0    1           2         3
# 0     25   41       23543        ds
# 1     67   58       43543   bigdata
# 2    689  698         454  web dev
# 0  frank  100   frank@abc       blr
# 1  shank  200  shank1@abc       blr
# 2   tank  300    tank@abc       blr

# %%
#merge operation 

data4 ={'emp_id':[101,102,103],
        'salary':[123,1234,1235],
        'pf':[45,85,95]
       }

# %%
data5 = { 'Emp_id':[101,102,451],
         'mob_no' : [3434,5656,767],
          'house_nu' : [345,345,345]
}

# %%
df4 = pd.DataFrame(data4)

df4
# Out:
#    emp_id  salary  pf
# 0     101     123  45
# 1     102    1234  85
# 2     103    1235  95

# %%
df5 = pd.DataFrame(data5)
df5
# Out:
#    Emp_id  mob_no  house_nu
# 0     101    3434       345
# 1     102    5656       345
# 2     451     767       345

# %%
merged_df = pd.merge(df4, df5, how='right')
merged_df
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 merged_df = pd.merge(df4, df5, how='right')
#       2 merged_df
#
# File D:\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
#if key value are matching 
pd.merge(df4,df5 , left_on = 'emp_id', right_on = 'Emp_id')
# Out:
#    emp_id  salary  pf  Emp_id  mob_no  house_nu
# 0     101     123  45     101    3434       345
# 1     102    1234  85     102    5656       345

# %%
#merge on 2 different diff key
data8 = {'emp_id' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data9  = {'emp_id' : [101,102,104,105,123],
          'salary' : [234, 345,200,878,43],
          'house_nu' : [345,345,345,56,234]
    
}

# %%
df8 = pd.DataFrame(data8)

# %%
df9 = pd.DataFrame(data9)

# %%
#if keys are matching only in that case 
pd.merge(df8,df9, on = ["emp_id","salary"])
# Out:
#    emp_id  salary  pf  house_nu
# 0     101     234  23       345
# 1     102     345  34       345

# %%
data10={'emp_id1': [101,102,103,104],
         'salary1': [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data11= {'emp_id2': [101,102,104,105,123],
          'salary2': [234, 345,200,878,43],
          'house_nu' : [345,345,345,56,234]
    
}

# %%
df11 = pd.DataFrame(data11, index = ['a','b','c','d','e'])

# %%
df10 = pd.DataFrame(data10, index = ['a','b','c','d'])

# %%
df11
# Out:
#    emp_id2  salary2  house_nu
# a      101      234       345
# b      102      345       345
# c      104      200       345
# d      105      878        56
# e      123       43       234

# %%
df10
# Out:
#    emp_id1  salary1  pf
# a      101      234  23
# b      102      345  34
# c      103      200  56
# d      104      400  78

# %%
#join operation -> match on indexes if same (default left join)
#it is same as merge operation but merge matches on columns and joins on row indexes
df10.join(df11)
# Out:
#    emp_id1  salary1  pf  emp_id2  salary2  house_nu
# a      101      234  23      101      234       345
# b      102      345  34      102      345       345
# c      103      200  56      104      200       345
# d      104      400  78      105      878        56

# %%
#load data
df_sales=pd.read_csv(r'C:\Users\ferna\OneDrive\Desktop\I -nueron\pandas_dataset\Attribute DataSet.csv')

# %%
df_sales
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df_sales.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
#create a new column and store derieved data from somewhere else
#will do for recommendation to make or close the production

#apply f()
df_sales['flag'] = df_sales['Recommendation'].apply(flag)

# %%
df_sales
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#store dress_id  length
df_sales['len_dressid'] = df_sales['Dress_ID'].astype(str).apply(len)

# %%
df_sales
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
def rating_flag(a):
    if a < 3:
        return 'low'
    else:
        return 'high'

# %%
df_sales['flag_Rating'] = df_sales['Rating'].apply(rating_flag)

# %%
df_sales.head(15)
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 0   1006032852      Sexy      Low     4.6     M  Summer     o-neck
# 1   1212192089    Casual      Low     0.0     L  Summer     o-neck
# 2   1190380701   vintage     High     0.0     L  Automn     o-neck
# 3    966005983     Brief  Average     4.6     L  Spring     o-neck
# 4    876339541      cute      Low     4.5     M  Summer     o-neck
# 5   1068332458  bohemian      Low     0.0     M  Summer     v-neck
# 6   1220707172    Casual  Average     0.0    XL  Summer     o-neck
# 7   1219677488   Novelty  Average     0.0  free  Automn     o-neck
# 8   1113094204     Flare  Average     0.0  free  Spring     v-neck
# 9    985292672  bohemian      Low     0.0  free  Summer     v-neck
# 10  1117293701     party  Average     5.0  free  Summer     o-neck
# 11   898481530     Flare  Average     0.0  free  Spring     v-neck
# 12   957723897      sexy      Low     4.7     M  Winter     o-neck
# ...

# %%
#lambda f()
